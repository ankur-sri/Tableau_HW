# %%
# Add dependencies
import glob
import pandas as pd

# %%
clean_data_riders_df = pd.concat([pd.read_csv(f) for f in glob.glob('../citiBike/Citi-Bike_HW/2018_data/Riders_data_raw2018/*.csv')], ignore_index = True)
clean_data_members = pd.concat([pd.read_csv(f) for f in glob.glob('../citiBike/Citi-Bike_HW/2018_data/membership_data2018/*.csv')], ignore_index = True)

# %%
clean_data_riders = clean_data_riders_df.head(15000000)
clean_data_riders.head(5)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929           505.0          6 Ave & W 33 St
# ...

# %%
clean_data_riders.count()
# Out:
# tripduration               15000000
# starttime                  15000000
# stoptime                   15000000
# start station id           14997699
# start station name         14997699
# start station latitude     15000000
# start station longitude    15000000
# end station id             14997699
# end station name           14997699
# end station latitude       15000000
# end station longitude      15000000
# bikeid                     15000000
# usertype                   15000000
# birth year                 15000000
# gender                     15000000
# dtype: int64

# %%
clean_data_members.head()
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/2018                                               5499
# 1  1/2/2018                                              18818
# 2  1/3/2018                                              24299
# 3  1/4/2018                                               1922
# 4  1/5/2018                                               4972
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        11483
# 1                                        39352
# 2                                        42853
# 3                                         5328
# 4                                        14303
#
#    Total Annual Members (All Time)  \
# 0                           253490
# 1                           253558
# 2                           253591
# 3                           253604
# 4                           253614
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
clean_data_members.count()
# Out:
# Date                                                  365
# Trips over the past 24-hours (midnight to 11:59pm)    365
# Miles traveled today (midnight to 11:59 pm)           365
# Total Annual Members (All Time)                       365
# 24-Hour Passes Purchased (midnight to 11:59 pm)       365
# 3-Day Passes Purchased (midnight to 11:59 pm)         365
# dtype: int64

# %%
 # Export to csv
clean_data_riders.to_csv("../citiBike/Citi-Bike_HW/2018_data/CleanBikeData2018/trips_2018.csv")
clean_data_members.to_csv("../citiBike/Citi-Bike_HW/2018_data/CleanBikeData2018/2018_members.csv")
